# %% [markdown]
# # Identifying the most dangerous junctions in the UK

# %%
#main
import pandas as pd
import numpy as np
import math

#graphic
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

#warnings
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
raw_df = pd.read_csv('Accident_NaNs_imputed.csv')
raw_df.shape
# Out:
# (597840, 40)

# %%
raw_df.drop_duplicates(subset=['accident_index'], inplace =True)

# %%
raw_df['junction_detail'].value_counts(dropna=False) # 0 means 'Not at junction or within 20 metres'
# Out:
# 0.0    254049
# 3.0    176873
# 6.0     56609
# 1.0     48961
# 9.0     23305
# 8.0     14942
# 5.0      8504
# 2.0      7762
# 7.0      6835
# Name: junction_detail, dtype: int64

# %%
raw_df['junction_control'].value_counts(dropna=False)
# Out:
# 4.0    526550
# 2.0     65342
# 3.0      3597
# 1.0      1959
# 0.0       392
# Name: junction_control, dtype: int64

# %%
raw_df['accident_severity'].value_counts(dropna=False)
# Out:
# 3    481638
# 2    108112
# 1      8090
# Name: accident_severity, dtype: int64

# %%
raw_df['accident_severity']= raw_df['accident_severity'].replace({1:'Serious', 2:'Serious', 3:'Slight'}).astype(object)

# %%
raw_df['accident_severity'].value_counts(dropna=False)
# Out:
# Slight     481638
# Serious    116202
# Name: accident_severity, dtype: int64

# %%
junction_df = raw_df[(raw_df['junction_detail'] != 0.0) & (raw_df['accident_severity']=='Serious')]

# %%
junction_df.shape
# Out:
# (60683, 40)

# %%
junction_df[['latitude','longitude']] = junction_df[['latitude','longitude']].apply(lambda x: round(x,3))

# %%
def latlong_combine(row):
    lat= row['latitude']
    long= row['longitude']
    return str(lat) + ", " + str(long)

junction_df['latlong'] = junction_df.apply(latlong_combine, axis=1)

# %%
junction_df.head()
# Out:
#     Unnamed: 0  accident_year  location_easting_osgr  location_northing_osgr  \
# 18          18           2016               516350.0                175710.0
# 59          59           2016               531430.0                178020.0
# 63          63           2016               515430.0                180170.0
# 70          70           2016               536210.0                182860.0
# 85          85           2016               550990.0                190170.0
#
#     longitude  latitude  number_of_vehicles  number_of_casualties  \
# 18     -0.326    51.468                   1                     1
# 59     -0.108    51.486                   2                     1
# 63     -0.338    51.509                   1                     2
# 70     -0.038    51.528                   1                     1
# 85      0.178    51.590                   2                     1
#
#    accident_index accident_reference  police_force accident_severity  \
# 18  2016010000048          010000048             1           Serious
# 59  2016010000116          010000116             1           Serious
# 63  2016010000121          010000121             1           Serious
# 70  2016010000132          010000132             1           Serious
# 85  2016010000163          010000163             1           Serious
#
#     day_of_week   time  local_authority_district local_authority_ons_district  \
# 18            3  07:10                      25.0                    E09000018
# 59            4  06:25                       9.0                    E09000022
# 63            4  09:50                      27.0                    E09000009
# 70            4  08:24                       5.0                    E09000030
# 85            3  13:27                      15.0                    E09000016
#
#    local_authority_highway  first_road_class  first_road_number  road_type  \
# 18               E09000018                 3               3004        6.0
# 59               E09000022                 3                  3        3.0
# 63               E09000009                 3               4020        6.0
# 70               E09000030                 3               1205        3.0
# 85               E09000016                 3                 12        3.0
#
#     speed_limit  junction_detail  junction_control  second_road_class  \
# 18         30.0              3.0               4.0                6.0
# 59         30.0              3.0               2.0                3.0
# 63         30.0              6.0               2.0                3.0
# 70         20.0              3.0               4.0                6.0
# 85         50.0              3.0               4.0                6.0
#
#     second_road_number  pedestrian_crossing_human_control  \
# 18                 0.0                                0.0
# 59                 3.0                                0.0
# 63              3002.0                                0.0
# 70                 0.0                                0.0
# 85                 0.0                                0.0
#
#     pedestrian_crossing_physical_facilities  light_conditions  \
# 18                                      4.0               1.0
# 59                                      5.0               1.0
# 63                                      4.0               1.0
# 70                                      1.0               1.0
# 85                                      0.0               1.0
#
#     weather_conditions  road_surface_conditions  special_conditions_at_site  \
# 18                 1.0                      1.0                         0.0
# 59                 1.0                      1.0                         0.0
# 63                 1.0                      1.0                         0.0
# 70                 1.0                      1.0                         0.0
# 85                 1.0                      1.0                         0.0
#
#     carriageway_hazards  urban_or_rural_area  \
# 18                  2.0                  1.0
# 59                  0.0                  1.0
# 63                  0.0                  1.0
# 70                  0.0                  1.0
# 85                  0.0                  1.0
#
#     did_police_officer_attend_scene_of_accident  trunk_road_flag  \
# 18                                          1.0              2.0
# 59                                          1.0              2.0
# 63                                          1.0              2.0
# 70                                          1.0              2.0
# 85                                          1.0              2.0
#
#    lsoa_of_accident_location  month  hour easting_binned northing_binned  \
# 18                 E01002667      1     7              J               N
# 59                 E01003107      2     6              J               N
# 63                 E01001252      2     9              J               N
# 70                 E01004230      2     8              J               N
# 85                 E01002334      1    13              J               N
#
#            latlong
# 18  51.468, -0.326
# 59  51.486, -0.108
# 63  51.509, -0.338
# 70  51.528, -0.038
# 85    51.59, 0.178

# %%
junction_df.columns
# Out:
# Index(['Unnamed: 0', 'accident_year', 'location_easting_osgr',
#        'location_northing_osgr', 'longitude', 'latitude', 'number_of_vehicles',
#        'number_of_casualties', 'accident_index', 'accident_reference',
#        'police_force', 'accident_severity', 'day_of_week', 'time',
#        'local_authority_district', 'local_authority_ons_district',
#        'local_authority_highway', 'first_road_class', 'first_road_number',
#        'road_type', 'speed_limit', 'junction_detail', 'junction_control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident',
#        'trunk_road_flag', 'lsoa_of_accident_location', 'month', 'hour',
#        'easting_binned', 'northing_binned', 'latlong'],
#       dtype='object')

# %%
junction_df = junction_df[['accident_index','latitude','longitude','latlong', 'number_of_vehicles',
                           'number_of_casualties',  'accident_severity','local_authority_district',
                           'junction_detail', 'junction_control','road_type',
                           'first_road_class', 'first_road_number',
                           'second_road_class', 'second_road_number']]

# %%
junction_df.shape
# Out:
# (60683, 15)

# %%
junction_df.sort_values(by = ['number_of_casualties'], ascending = False).head(10)
# Out:
#        accident_index  longitude  latitude         latlong  \
# 75624   201634NE09806     -0.469    52.505  52.505, -0.469
# 122918  2016551602181     -2.454    50.612  50.612, -2.454
# 67153   2016300018272     -1.421    53.240   53.24, -1.421
# 458574  2019350900122     -0.043    52.359  52.359, -0.043
# 464665  2019410889448     -0.195    51.889  51.889, -0.195
# 136099  201697UC70210     -4.430    55.576   55.576, -4.43
# 594904  2020990939366     -2.940    56.548   56.548, -2.94
# 472728  2019440129002     -1.346    50.703  50.703, -1.346
# 106496  2016460111374      0.515    51.394   51.394, 0.515
# 226874  2017430254240     -0.749    52.084  52.084, -0.749
#
#         number_of_vehicles  number_of_casualties accident_severity  \
# 75624                    2                    58           Serious
# 122918                   2                    27           Serious
# 67153                    3                    21           Serious
# 458574                   2                    20           Serious
# 464665                   2                    19           Serious
# 136099                   1                    19           Serious
# 594904                   2                    19           Serious
# 472728                   3                    19           Serious
# 106496                   4                    15           Serious
# 226874                   3                    14           Serious
#
#         local_authority_district  junction_detail  junction_control  \
# 75624                      382.0              6.0               4.0
# 122918                     646.0              1.0               4.0
# 67153                      322.0              3.0               4.0
# 458574                     393.0              6.0               4.0
# 464665                     435.0              9.0               4.0
# 136099                     919.0              1.0               4.0
# 594904                     912.0              3.0               4.0
# 472728                     505.0              6.0               4.0
# 106496                     544.0              9.0               4.0
# 226874                     479.0              5.0               4.0
#
#         road_type  first_road_class  first_road_number  second_road_class  \
# 75624         6.0                 5                  0                5.0
# 122918        6.0                 5                  0                6.0
# 67153         6.0                 4               6543                6.0
# 458574        6.0                 4               1040                6.0
# 464665        6.0                 4                197                6.0
# 136099        1.0                 3                 76                3.0
# 594904        3.0                 3                928                3.0
# 472728        6.0                 3               3054                6.0
# 106496        6.0                 6                  0                6.0
# 226874        3.0                 1                  1                1.0
#
#         second_road_number
# 75624                  0.0
# 122918                 0.0
# 67153                  0.0
# 458574                 0.0
# 464665                 0.0
# 136099               719.0
# 594904                90.0
# 472728                 0.0
# 106496                 0.0
# 226874                 1.0

# %%
most_dangerous_junctions=junction_df.groupby(['latlong','latitude','longitude','local_authority_district','junction_control', 'junction_detail']).agg(
    {'number_of_casualties': sum,'number_of_vehicles': sum}).sort_values(
                                                by=['number_of_casualties'], ascending=False).head(54)

most_dangerous_junctions # junctions with 100 and more casualties over a 5 year period (2016-2020)

# Almost all of them are 'Give way or uncontrolled' (junction_control=4)
# My preventative action proposal is installation of traffic lights to these junctions. 
# In addition to that, presence of traffic police at these junctions from time to time may help 
# enforce the law and having more control of accidents in these hotspots.
# Out:
#                                                                                              number_of_casualties  \
# latlong        latitude longitude local_authority_district junction_control junction_detail
# 52.505, -0.469 52.505   -0.469    382.0                    4.0              6.0                                62
# 53.358, -0.19  53.358   -0.190    351.0                    4.0              6.0                                30
# 50.612, -2.454 50.612   -2.454    646.0                    4.0              1.0                                27
# 50.703, -1.346 50.703   -1.346    505.0                    4.0              6.0                                23
# 52.359, -0.043 52.359   -0.043    393.0                    4.0              6.0                                23
# 56.548, -2.94  56.548   -2.940    912.0                    4.0              3.0                                22
# 53.24, -1.421  53.240   -1.421    322.0                    4.0              3.0                                21
# 55.576, -4.43  55.576   -4.430    919.0                    4.0              1.0                                19
# 51.889, -0.195 51.889   -0.195    435.0                    4.0              9.0                                19
# 51.394, 0.515  51.394    0.515    544.0                    4.0              9.0                                15
# 53.472, -1.036 53.472   -1.036    211.0                    4.0              8.0                                15
# 53.256, 0.095  53.256    0.095    351.0                    4.0              3.0                                14
# 53.478, -2.234 53.478   -2.234    102.0                    2.0              3.0                                14
# 53.106, -1.213 53.106   -1.213    340.0                    2.0              6.0                                14
# 51.653, -0.06  51.653   -0.060    32.0                     2.0              3.0                                14
# 52.084, -0.749 52.084   -0.749    479.0                    4.0              5.0                                14
# 52.748, -1.302 52.748   -1.302    362.0                    4.0              6.0                                13
# 51.515, -0.142 51.515   -0.142    1.0                      2.0              6.0                                13
# 50.805, 0.053  50.805    0.053    554.0                    4.0              3.0                                13
# 51.517, -0.089 51.517   -0.089    570.0                    2.0              6.0                                13
# 53.802, -1.533 53.802   -1.533    204.0                    4.0              3.0                                13
# 56.495, -2.95  56.495   -2.950    918.0                    4.0              1.0                                13
# 51.111, 0.854  51.111    0.854    530.0                    4.0              6.0                                12
# 52.636, -1.159 52.636   -1.159    364.0                    2.0              6.0                                12
# 51.048, 0.371  51.048    0.371    555.0                    4.0              3.0                                12
# 52.637, -2.526 52.637   -2.526    286.0                    4.0              3.0                                12
# 52.341, -2.195 52.341   -2.195    278.0                    4.0              3.0                                12
# 53.469, -2.216 53.469   -2.216    102.0                    2.0              6.0                                12
# 53.514, -2.247 53.514   -2.247    102.0                    4.0              3.0                                12
# 52.859, -1.602 52.859   -1.602    328.0                    4.0              6.0                                12
# 51.328, -1.239 51.328   -1.239    490.0                    4.0              3.0                                12
# 53.489, -2.101 53.489   -2.101    110.0                    4.0              3.0                                12
# 52.504, 0.083  52.504    0.083    392.0                    4.0              3.0                                11
# 51.583, 0.561  51.583    0.561    450.0                    4.0              1.0                                11
# 51.75, -1.244  51.750   -1.244    482.0                    4.0              1.0                                11
# 51.354, -0.677 51.354   -0.677    515.0                    4.0              9.0                                11
# 51.112, -1.578 51.112   -1.578    501.0                    4.0              6.0                                11
# 53.253, -3.202 53.253   -3.202    724.0                    4.0              5.0                                11
# 52.578, -1.987 52.578   -1.987    307.0                    2.0              6.0                                11
# 55.065, -2.078 55.065   -2.078    139.0                    4.0              6.0                                11
# 52.222, -0.148 52.222   -0.148    395.0                    4.0              3.0                                11
# 53.493, -2.954 53.493   -2.954    93.0                     2.0              6.0                                10
# 52.902, -3.043 52.902   -3.043    286.0                    4.0              3.0                                10
# 50.834, -0.189 50.834   -0.189    565.0                    4.0              3.0                                10
# 50.979, -1.514 50.979   -1.514    501.0                    4.0              3.0                                10
# 53.136, -0.718 53.136   -0.718    345.0                    4.0              3.0                                10
# 53.44, -0.723  53.440   -0.723    356.0                    4.0              3.0                                10
# 51.584, -2.988 51.584   -2.988    733.0                    2.0              6.0                                10
# 56.204, -3.475 56.204   -3.475    934.0                    4.0              6.0                                10
# 53.768, -0.354 53.768   -0.354    228.0                    2.0              6.0                                10
# 53.949, -1.304 53.949   -1.304    182.0                    4.0              6.0                                10
# 50.899, -1.392 50.899   -1.392    500.0                    2.0              6.0                                10
# 55.819, -4.234 55.819   -4.234    926.0                    4.0              3.0                                10
# 51.378, 0.228  51.378    0.228    538.0                    4.0              3.0                                10
#
#                                                                                              number_of_vehicles
# latlong        latitude longitude local_authority_district junction_control junction_detail
# 52.505, -0.469 52.505   -0.469    382.0                    4.0              6.0                               6
# 53.358, -0.19  53.358   -0.190    351.0                    4.0              6.0                              16
# 50.612, -2.454 50.612   -2.454    646.0                    4.0              1.0                               2
# 50.703, -1.346 50.703   -1.346    505.0                    4.0              6.0                               9
# 52.359, -0.043 52.359   -0.043    393.0                    4.0              6.0                               6
# 56.548, -2.94  56.548   -2.940    912.0                    4.0              3.0                               4
# 53.24, -1.421  53.240   -1.421    322.0                    4.0              3.0                               3
# 55.576, -4.43  55.576   -4.430    919.0                    4.0              1.0                               1
# 51.889, -0.195 51.889   -0.195    435.0                    4.0              9.0                               2
# 51.394, 0.515  51.394    0.515    544.0                    4.0              9.0                               4
# 53.472, -1.036 53.472   -1.036    211.0                    4.0              8.0                               4
# 53.256, 0.095  53.256    0.095    351.0                    4.0              3.0                               8
# 53.478, -2.234 53.478   -2.234    102.0                    2.0              3.0                               3
# 53.106, -1.213 53.106   -1.213    340.0                    2.0              6.0                               9
# 51.653, -0.06  51.653   -0.060    32.0                     2.0              3.0                              12
# 52.084, -0.749 52.084   -0.749    479.0                    4.0              5.0                               3
# 52.748, -1.302 52.748   -1.302    362.0                    4.0              6.0                              11
# 51.515, -0.142 51.515   -0.142    1.0                      2.0              6.0                              15
# 50.805, 0.053  50.805    0.053    554.0                    4.0              3.0                              13
# 51.517, -0.089 51.517   -0.089    570.0                    2.0              6.0                              10
# 53.802, -1.533 53.802   -1.533    204.0                    4.0              3.0                               2
# 56.495, -2.95  56.495   -2.950    918.0                    4.0              1.0                               7
# 51.111, 0.854  51.111    0.854    530.0                    4.0              6.0                               9
# 52.636, -1.159 52.636   -1.159    364.0                    2.0              6.0                               9
# 51.048, 0.371  51.048    0.371    555.0                    4.0              3.0                               1
# 52.637, -2.526 52.637   -2.526    286.0                    4.0              3.0                               5
# 52.341, -2.195 52.341   -2.195    278.0                    4.0              3.0                              11
# 53.469, -2.216 53.469   -2.216    102.0                    2.0              6.0                              14
# 53.514, -2.247 53.514   -2.247    102.0                    4.0              3.0                               7
# 52.859, -1.602 52.859   -1.602    328.0                    4.0              6.0                               9
# 51.328, -1.239 51.328   -1.239    490.0                    4.0              3.0                              12
# 53.489, -2.101 53.489   -2.101    110.0                    4.0              3.0                               2
# 52.504, 0.083  52.504    0.083    392.0                    4.0              3.0                               3
# 51.583, 0.561  51.583    0.561    450.0                    4.0              1.0                               6
# 51.75, -1.244  51.750   -1.244    482.0                    4.0              1.0                              22
# 51.354, -0.677 51.354   -0.677    515.0                    4.0              9.0                               4
# 51.112, -1.578 51.112   -1.578    501.0                    4.0              6.0                              10
# 53.253, -3.202 53.253   -3.202    724.0                    4.0              5.0                               2
# 52.578, -1.987 52.578   -1.987    307.0                    2.0              6.0                               9
# 55.065, -2.078 55.065   -2.078    139.0                    4.0              6.0                               7
# 52.222, -0.148 52.222   -0.148    395.0                    4.0              3.0                               6
# 53.493, -2.954 53.493   -2.954    93.0                     2.0              6.0                               6
# 52.902, -3.043 52.902   -3.043    286.0                    4.0              3.0                               4
# 50.834, -0.189 50.834   -0.189    565.0                    4.0              3.0                               4
# 50.979, -1.514 50.979   -1.514    501.0                    4.0              3.0                               4
# 53.136, -0.718 53.136   -0.718    345.0                    4.0              3.0                               7
# 53.44, -0.723  53.440   -0.723    356.0                    4.0              3.0                               2
# 51.584, -2.988 51.584   -2.988    733.0                    2.0              6.0                              11
# 56.204, -3.475 56.204   -3.475    934.0                    4.0              6.0                               2
# 53.768, -0.354 53.768   -0.354    228.0                    2.0              6.0                               9
# 53.949, -1.304 53.949   -1.304    182.0                    4.0              6.0                               5
# 50.899, -1.392 50.899   -1.392    500.0                    2.0              6.0                              17
# 55.819, -4.234 55.819   -4.234    926.0                    4.0              3.0                               2
# 51.378, 0.228  51.378    0.228    538.0                    4.0              3.0                               3

# %%
# most_dangerous_junctions.to_csv('most_dangerous_junctions.csv')
